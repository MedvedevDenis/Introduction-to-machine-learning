# %%
import pandas as pd
from sklearn.cluster import KMeans
from skimage.io import imread
import pylab
from skimage.util import img_as_float
import numpy as np
import matplotlib.pyplot as plt

# %%
image = imread("parrots.jpg")

# %%
pylab.imshow(image)

# %%
def PSNR(original, compressed):
    mse = np.mean((original - compressed) ** 2)
    psnr = 10 * np.log10(1 / mse)
    return psnr

# %%
X = img_as_float(image=image)

# %%
original_shape = X.shape

# %%
original_shape
# Out:
# (474, 713, 3)

# %%
X = X.reshape((-1,3))

# %%
X.shape
# Out:
# (337962, 3)

# %%
df = pd.DataFrame()
df["R"], df["G"], df["B"] = X[:, 0], X[:, 1], X[:, 2]
X_original = df[["R", "G", "B"]].values

# %%
df.head()
# Out:
#           R         G         B
# 0  0.015686  0.494118  0.019608
# 1  0.011765  0.490196  0.015686
# 2  0.007843  0.494118  0.007843
# 3  0.007843  0.494118  0.007843
# 4  0.007843  0.501961  0.011765

# %%
for n_clusters in range(1,21):
    kmeans = KMeans(n_clusters=n_clusters, init="k-means++", random_state=241)
    
    df["labels"] = kmeans.fit_predict(X)
    
    mean_cluster_colors = df.groupby("labels").mean()
    median_cluster_colors = df.groupby("labels").median()
    
    df_mean, df_median = df.copy(), df.copy()
    
    for i in range(n_clusters):    
        df_mean.loc[df.labels == i, "R"] = mean_cluster_colors.iloc[i]["R"]
        df_mean.loc[df.labels == i, "G"] = mean_cluster_colors.iloc[i]["G"]
        df_mean.loc[df.labels == i, "B"] = mean_cluster_colors.iloc[i]["B"]

        df_median.loc[df.labels == i, "R"] = median_cluster_colors.iloc[i]["R"]
        df_median.loc[df.labels == i, "G"] = median_cluster_colors.iloc[i]["G"]
        df_median.loc[df.labels == i, "B"] = median_cluster_colors.iloc[i]["B"]
    
    X_mean = df_mean[["R", "G", "B"]].values
    X_median = df_median[["R", "G", "B"]].values
    
    psnr_mean = PSNR(X_original.reshape(original_shape), X_mean.reshape(original_shape))
    psnr_median = PSNR(X_original.reshape(original_shape), X_mean.reshape(original_shape))
    
    
    print(n_clusters, psnr_mean, psnr_median)
    
    fig,ax = plt.subplots(1,2)
    
    ax[0].imshow(X_mean.reshape(original_shape))
    ax[1].imshow(X_median.reshape(original_shape))
    
    if psnr_mean > 20 or psnr_median >20:
        break
# Out:
# 1 9.837758895356927 9.837758895356927
# 2 12.112035581526712 12.112035581526712
# 3 13.176025694009377 13.176025694009377
# 4 14.394294489218186 14.394294489218186
# 5 15.559946338767901 15.559946338767901
# 6 16.57272547166087 16.57272547166087
# 7 17.671923270880107 17.671923270880107
# 8 18.46813382718831 18.46813382718831
# 9 19.14487020268468 19.14487020268468
# 10 19.675498079721166 19.675498079721166
# 11 20.162160628278038 20.162160628278038
